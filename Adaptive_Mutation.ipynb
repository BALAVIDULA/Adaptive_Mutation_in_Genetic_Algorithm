# %%
# !pip install pygad

# %%
import pygad
import numpy

function_ip = [2, -4, -3.4, 6]
desired_op = 55

def fitness_func(ga_instance,solution, solution_idx):
    solution = numpy.array(solution)
    output = numpy.sum(solution * numpy.array(function_ip))
    fitness = 1.0 / (numpy.abs(output - desired_op) + 0.000001)
    return fitness
fitness_function = fitness_func
ga_instance = pygad.GA(
    num_generations=100,
    sol_per_pop=5,
    num_genes=4,
    num_parents_mating=2,
    fitness_func=fitness_function,
    mutation_type="random"
)

ga_instance.run()
solution, solution_fitness, solution_idx = ga_instance.best_solution()

ga_instance.plot_fitness()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))

prediction = numpy.sum(numpy.array(function_ip)*solution)
print("Predicted output based on the best solution : {prediction}".format(prediction=prediction))
# Out:
# Parameters of the best solution : [ 5.7796213  -1.47227116 -4.20081113  3.87842684]
# Fitness value of the best solution = 607.1093757464682
# Predicted output based on the best solution : 55.00164614965696

# %%
mutation_percent_genes=[0.57, 0.32]
ga_instance_am = pygad.GA(
    num_generations=100,
    sol_per_pop=5,
    num_genes=4,
    num_parents_mating=2,
    fitness_func=fitness_function,
    mutation_percent_genes=mutation_percent_genes,
    mutation_type="adaptive"
)

ga_instance_am.run()
solution_am, solution_fitness_am, solution_idx_am = ga_instance_am.best_solution()

ga_instance_am.plot_fitness()
# Out:
# /usr/local/lib/python3.10/dist-packages/pygad/pygad.py:774: UserWarning: The percentage of genes to mutate (0.57) resulted in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   warnings.warn(f"The percentage of genes to mutate ({mutation_percent_genes[idx]}) resulted in selecting ({mutation_num_genes[idx]}) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).\nIf you do not want to mutate any gene, please set mutation_type=None.")
# /usr/local/lib/python3.10/dist-packages/pygad/pygad.py:774: UserWarning: The percentage of genes to mutate (0.32) resulted in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
# ...

# %%
print("Parameters of the best solution : {solution}".format(solution=solution_am))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness_am))

prediction_am = numpy.sum(numpy.array(function_ip)*solution_am)
print("Predicted output based on the best solution : {prediction}".format(prediction=prediction_am))
# Out:
# Parameters of the best solution : [ 1.41952762 -5.61786572  2.216942    6.20462296]
# Fitness value of the best solution = 1528.837714664155
# Predicted output based on the best solution : 55.00065309166088
